# %%
# Imports
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import re
import numpy as np
import helpers # this is a Joe G. created helper file of functions
from bertopic import BERTopic

# %%
# Params / Files to change 
input_file = '../data/cleaned_data/USAJobs.csv' # change to whatever file/filepath you are using
output_file = '../data/results/usa_jobs/similarity_match/batch2.csv' # change to your outpath
desc_column = 'Duties'
baseline_embedding_file = '../data/saved_embeddings/baseline.pickle' # Make None if you don't want to saev
sent_embedding_file = '../data/saved_embeddings/test_batch.pickle' #change to sentence embedding path
start_idx = 0 # file row to start at
end_idx = 100 # file row to end at
#how many jobs do you want to search / score against? make start_idx -1 if you want to use entire file

# %%
# Initialize Pre-trained model 
# downloads automatically from hugging face
model_name = 'sentence-transformers/paraphrase-distilroberta-base-v2'
model = SentenceTransformer(model_name)

# %%
# file for our cyber baseline
# hopefully can use embedding file later
# ? Is Knowledge_Units.csv the final baseline file? 
baseline_file = '../data/cleaned_data/KUKSAT_Baseline.csv'
ksa_col = 'KUKSAT'

# %%
# read baselne_file and convert to df
df_base = pd.read_csv(baseline_file, encoding='ISO-8859-1')
ksas = df_base[ksa_col].tolist()

# %%
# how many ksas
len(df_base)
# Out:
# 288

# %%
# read input file and covert to df
# covert target description column to list
df = pd.read_csv(input_file)
if start_idx >= 0 and start_idx != end_idx:
    jobs = df[start_idx:end_idx]
else:
    jobs = df.copy()
jobs = jobs[desc_column].tolist()

# %%
# how many jobs
len(jobs)
# Out:
# 100

# %%
# apply text cleanup functions to jobs and ksa base list
# jobs = helpers.remove_stopwords(jobs)
# ksas = helpers.remove_stopwords(ksas)

jobs = helpers.cleanup_text(jobs)
ksas = helpers.cleanup_text(ksas)

# %%
# split jobs to sentence level
job_sent = helpers.split_sents(jobs)
job_sent = [s for job in job_sent for s in job]

# %%
# no stop words in sents
topic_model = BERTopic(embedding_model=model)

topics, probs = topic_model.fit_transform(job_sent)

# %%
len(topic_model.get_topic_info()['Topic'].tolist())
# Out:
# 22

# %%
# saves topic model
topic_model.save('../data/results/usa_jobs/similarity_match/topicModel')

# %%
all_matches = []
all_similar =[]
for idx, ksa in enumerate(ksas):
    matched=[]
    similar=[]
    topics, similarity = topic_model.find_topics(ksa,top_n=10)

    for idx2, score in enumerate(similarity):
        temp={}
        if score >= 0.6:
            temp['ksa_idx'] = idx
            temp['ksa_text'] = ksas[idx]
            temp['topic_idx'] = idx2
            temp['sim_score'] = score
            temp['topic_info'] = topic_model.get_topic(idx2)
            matched.append(temp)
        if score <0.6 and score > 0.4:
            temp['ksa_idx'] = idx
            temp['ksa_text'] = ksas[idx]
            temp['topic_idx'] = idx2
            temp['sim_score'] = score
            temp['topic_info'] = topic_model.get_topic(idx2)
            similar.append(temp)
    all_matches.append(matched)
    all_similar.append(similar)

# %%
num_topics = topic_model.topics()

# %%
ksa_agg_matches = []
ksa_agg_similar = []
num_topics
for idx, val in enumerate(ksas):
    matched_score = len(all_matches[idx])/

# %%
final_df = pd.DataFrame({
    'ksa': ksas,
    'matches': all_matches,
    'similar': all_similar
})
# Out:
# [[],
#  [{'ksa_idx': 1,
#    'ksa_text': 'Vulnerabilities and Risk management include backups and recovery',
#    'topic_idx': 0,
#    'sim_score': 0.46687835039694586,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 2,
#    'ksa_text': 'Common Attacks',
#    'topic_idx': 0,
#    'sim_score': 0.4431535197523256,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 3,
#    'ksa_text': 'Basic Risk Assessment',
#    'topic_idx': 0,
#    'sim_score': 0.4636694771714077,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 4,
#    'ksa_text': 'Security Life Cycle',
#    'topic_idx': 0,
#    'sim_score': 0.4499922535850137,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 4,
#    'ksa_text': 'Security Life Cycle',
#    'topic_idx': 1,
#    'sim_score': 0.4254731249809245,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 9,
#    'ksa_text': 'Confidentiality, Integrity, Availability, Access, Authentication, Authorization, Non Repudiation, Privacy',
#    'topic_idx': 0,
#    'sim_score': 0.4368902394115397,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]},
#   {'ksa_idx': 9,
#    'ksa_text': 'Confidentiality, Integrity, Availability, Access, Authentication, Authorization, Non Repudiation, Privacy',
#    'topic_idx': 1,
#    'sim_score': 0.43401294348036157,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 9,
#    'ksa_text': 'Confidentiality, Integrity, Availability, Access, Authentication, Authorization, Non Repudiation, Privacy',
#    'topic_idx': 2,
#    'sim_score': 0.4137981830904875,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [],
#  [{'ksa_idx': 12,
#    'ksa_text': 'Security Mechanisms e.g., Identification Authentication, Audit',
#    'topic_idx': 0,
#    'sim_score': 0.46701568474268396,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 12,
#    'ksa_text': 'Security Mechanisms e.g., Identification Authentication, Audit',
#    'topic_idx': 1,
#    'sim_score': 0.4350000151247279,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 13,
#    'ksa_text': 'Malicious activity detection forms of attack',
#    'topic_idx': 0,
#    'sim_score': 0.4200225002596166,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 14,
#    'ksa_text': 'Appropriate Countermeasures',
#    'topic_idx': 0,
#    'sim_score': 0.46954515849668504,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 14,
#    'ksa_text': 'Appropriate Countermeasures',
#    'topic_idx': 1,
#    'sim_score': 0.4524525949085671,
#    'topic_info': [('investigation', 0.11342337209691052),
#     ('reports', 0.10803080950133923),
#     ('incidents', 0.10297823230414185),
#     ('evidence', 0.07014332516354292),
#     ('citizens', 0.060657437923747747),
#     ('reporting', 0.056489246174143366),
#     ('force', 0.0504103875986269),
#     ('manager', 0.048797453635206364),
#     ('air', 0.047492648450824966),
#     ('user', 0.04667042587403855)]},
#   {'ksa_idx': 14,
#    'ksa_text': 'Appropriate Countermeasures',
#    'topic_idx': 2,
#    'sim_score': 0.4097719638059667,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]},
#   {'ksa_idx': 14,
#    'ksa_text': 'Appropriate Countermeasures',
#    'topic_idx': 3,
#    'sim_score': 0.4082554466128243,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [],
#  [{'ksa_idx': 17,
#    'ksa_text': 'Separation of domains duties',
#    'topic_idx': 0,
#    'sim_score': 0.4481533375766189,
#    'topic_info': [('work', 0.045829871877168527),
#     ('mission', 0.04152713583424943),
#     ('subordinate', 0.03920691807590449),
#     ('of', 0.03910211302630034),
#     ('and', 0.036587723309692476),
#     ('supervisors', 0.03651257013518008),
#     ('objectives', 0.036475411303181715),
#     ('is', 0.03212159365238682),
#     ('availability', 0.031840555316911115),
#     ('to', 0.030797001561053243)]},
#   {'ksa_idx': 17,
#    'ksa_text': 'Separation of domains duties',
#    'topic_idx': 1,
#    'sim_score': 0.43440532970718126,
#    'topic_info': [('assigned', 0.35706789432711694),
#     ('duties', 0.3234118275362212),
#     ('performs', 0.2936959738579026),
#     ('other', 0.24726781359552646),
#     ('as', 0.18668457783451992),
#     ('perform', 0.13637551058665973),
#     ('band', 0.1354301286976758),
#     ('will', 0.10109850448270527),
#     ('you', 0.07881511774502568),
#     ('same', 0.0764049804365465)]},
#   {'ksa_idx': 17,
#    'ksa_text': 'Separation of domains duties',
#    'topic_idx': 2,
#    'sim_score': 0.4051927810558638,
#    'topic_info': [('provide', 0.06374103347620298),
#     ('development', 0.0633579362492307),
#     ('support', 0.060495502466421776),
#     ('architects', 0.05799271361207729),
#     ('developers', 0.05799271361207729),
#     ('customers', 0.0502687853862712),
#     ('design', 0.04966980397268282),
#     ('guidance', 0.04935161909938489),
#     ('and', 0.04859432821370717),
#     ('consult', 0.047779895418375164)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 23,
#    'ksa_text': 'Open Design',
#    'topic_idx': 0,
#    'sim_score': 0.43564906208798315,
#    'topic_info': [('provide', 0.06374103347620298),
#     ('development', 0.0633579362492307),
#     ('support', 0.060495502466421776),
#     ('architects', 0.05799271361207729),
#     ('developers', 0.05799271361207729),
#     ('customers', 0.0502687853862712),
#     ('design', 0.04966980397268282),
#     ('guidance', 0.04935161909938489),
#     ('and', 0.04859432821370717),
#     ('consult', 0.047779895418375164)]}],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 27,
#    'ksa_text': 'Fail Safe Defaults Fail Secure',
#    'topic_idx': 0,
#    'sim_score': 0.4191841709572379,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [{'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 0,
#    'sim_score': 0.456996443423431,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 1,
#    'sim_score': 0.442975076507381,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]},
#   {'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 2,
#    'sim_score': 0.4388817750359413,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]},
#   {'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 3,
#    'sim_score': 0.4357344843567755,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]},
#   {'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 4,
#    'sim_score': 0.4126376470868255,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 5,
#    'sim_score': 0.40657187686936486,
#    'topic_info': [('work', 0.045829871877168527),
#     ('mission', 0.04152713583424943),
#     ('subordinate', 0.03920691807590449),
#     ('of', 0.03910211302630034),
#     ('and', 0.036587723309692476),
#     ('supervisors', 0.03651257013518008),
#     ('objectives', 0.036475411303181715),
#     ('is', 0.03212159365238682),
#     ('availability', 0.031840555316911115),
#     ('to', 0.030797001561053243)]},
#   {'ksa_idx': 30,
#    'ksa_text': 'Usability',
#    'topic_idx': 6,
#    'sim_score': 0.4017335711155671,
#    'topic_info': [('cyberspace', 0.14781937685980184),
#     ('tactical', 0.05936818732101393),
#     ('operator', 0.05130909666314512),
#     ('operators', 0.047866134653953514),
#     ('advanced', 0.047006844366802185),
#     ('national', 0.04199210897747148),
#     ('for', 0.03935948687648244),
#     ('industrial', 0.039222933447960746),
#     ('emulate', 0.039222933447960746),
#     ('currency', 0.03772313566776796)]}],
#  [],
#  [{'ksa_idx': 32,
#    'ksa_text': 'Endpoint protection a. Workstations, servers, appliances, mobile devices, peripheral devices Printers, scanners, external storage',
#    'topic_idx': 0,
#    'sim_score': 0.450826689726246,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 32,
#    'ksa_text': 'Endpoint protection a. Workstations, servers, appliances, mobile devices, peripheral devices Printers, scanners, external storage',
#    'topic_idx': 1,
#    'sim_score': 0.43606349654056764,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [{'ksa_idx': 34,
#    'ksa_text': 'System Architectures a. Virtualization Containers b. Cloud',
#    'topic_idx': 0,
#    'sim_score': 0.4114357719022575,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]}],
#  [],
#  [{'ksa_idx': 36,
#    'ksa_text': 'Networks Internet, LANs, wireless',
#    'topic_idx': 0,
#    'sim_score': 0.5623278211981428,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [{'ksa_idx': 37,
#    'ksa_text': 'Network mapping enumeration and identification of network components',
#    'topic_idx': 0,
#    'sim_score': 0.4136017157060262,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [],
#  [{'ksa_idx': 39,
#    'ksa_text': 'Intrusion Detection and Prevention Systems, Incident Response',
#    'topic_idx': 0,
#    'sim_score': 0.42312185632598875,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 40,
#    'ksa_text': 'Managed Services',
#    'topic_idx': 0,
#    'sim_score': 0.4128415739720596,
#    'topic_info': [('provide', 0.06374103347620298),
#     ('development', 0.0633579362492307),
#     ('support', 0.060495502466421776),
#     ('architects', 0.05799271361207729),
#     ('developers', 0.05799271361207729),
#     ('customers', 0.0502687853862712),
#     ('design', 0.04966980397268282),
#     ('guidance', 0.04935161909938489),
#     ('and', 0.04859432821370717),
#     ('consult', 0.047779895418375164)]}],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 45,
#    'ksa_text': 'People and security social engineering',
#    'topic_idx': 0,
#    'sim_score': 0.41024744918315853,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 46,
#    'ksa_text': 'Physical and environmental security concerns',
#    'topic_idx': 0,
#    'sim_score': 0.4583006919701367,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 46,
#    'ksa_text': 'Physical and environmental security concerns',
#    'topic_idx': 1,
#    'sim_score': 0.4499384717101722,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 53,
#    'ksa_text': 'Cryptography in practice a. Common Cryptographic Protocols b. DES AES evolution from DES to AES c. Cryptographic Modes and their strengths and weaknesses d. Cryptographic standards FIPS 140 series',
#    'topic_idx': 0,
#    'sim_score': 0.42373936808141965,
#    'topic_info': [('comsec', 0.17163038717356974),
#     ('cryptographic', 0.08816492666061557),
#     ('key', 0.08607341946981509),
#     ('materials', 0.0735151485813309),
#     ('management', 0.06471720231739433),
#     ('system', 0.06258042758710489),
#     ('ekms', 0.06057924309242815),
#     ('electronic', 0.05833803234254818),
#     ('destruction', 0.04408246333030778),
#     ('material', 0.042987244259156544)]}],
#  [],
#  [],
#  [{'ksa_idx': 56,
#    'ksa_text': 'Network media wired, optical, and wireless',
#    'topic_idx': 0,
#    'sim_score': 0.4703891445148727,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [{'ksa_idx': 57,
#    'ksa_text': 'Network Architectures and topologies PAN, LAN WAN, DMZ, Enclaves, VLAN, NAT, subnetting, supernetting',
#    'topic_idx': 0,
#    'sim_score': 0.42360308949221764,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [{'ksa_idx': 58,
#    'ksa_text': 'Common Network Devices and their role in the network. Routers, Switches, Hosts, VPNs, Firewalls',
#    'topic_idx': 0,
#    'sim_score': 0.40175888313388775,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [],
#  [{'ksa_idx': 60,
#    'ksa_text': 'Network Services and protocols introduction DNS, NTP, VLAN, etc. .',
#    'topic_idx': 0,
#    'sim_score': 0.4389924188822901,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [],
#  [{'ksa_idx': 62,
#    'ksa_text': 'Use of basic network administration tools.',
#    'topic_idx': 0,
#    'sim_score': 0.5433391451429861,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]},
#   {'ksa_idx': 62,
#    'ksa_text': 'Use of basic network administration tools.',
#    'topic_idx': 1,
#    'sim_score': 0.4061091334686705,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 72,
#    'ksa_text': 'Network Operations a. Network Security Monitoring b. Network Traffic Analysis',
#    'topic_idx': 0,
#    'sim_score': 0.41785532196677505,
#    'topic_info': [('network', 0.07310313291510342),
#     ('systems', 0.05026383881299889),
#     ('area', 0.048996426252978176),
#     ('networks', 0.04846706443623386),
#     ('installation', 0.04820481013499563),
#     ('wide', 0.04448415148245305),
#     ('lan', 0.03915232772493355),
#     ('and', 0.039057270088230366),
#     ('access', 0.03707827741342931),
#     ('the', 0.03414037268412)]}],
#  [],
#  [{'ksa_idx': 74,
#    'ksa_text': 'Privileged and non privileged states',
#    'topic_idx': 0,
#    'sim_score': 0.4145372894277497,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 80,
#    'ksa_text': 'Fundamental security design principles as applied to an OS',
#    'topic_idx': 0,
#    'sim_score': 0.482625277866913,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 80,
#    'ksa_text': 'Fundamental security design principles as applied to an OS',
#    'topic_idx': 1,
#    'sim_score': 0.41875527784688105,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 81,
#    'ksa_text': 'Access controls models and mechanisms',
#    'topic_idx': 0,
#    'sim_score': 0.44039775316775276,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]}],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 86,
#    'ksa_text': 'Events that indicate an attack is has happened',
#    'topic_idx': 0,
#    'sim_score': 0.4239063376277582,
#    'topic_info': [('investigation', 0.11342337209691052),
#     ('reports', 0.10803080950133923),
#     ('incidents', 0.10297823230414185),
#     ('evidence', 0.07014332516354292),
#     ('citizens', 0.060657437923747747),
#     ('reporting', 0.056489246174143366),
#     ('force', 0.0504103875986269),
#     ('manager', 0.048797453635206364),
#     ('air', 0.047492648450824966),
#     ('user', 0.04667042587403855)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 97,
#    'ksa_text': 'Making cybersecurity a strategic essential part of core organizational strategy',
#    'topic_idx': 0,
#    'sim_score': 0.4250490261763513,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [{'ksa_idx': 99,
#    'ksa_text': 'Develop processes and procedures for incident response',
#    'topic_idx': 0,
#    'sim_score': 0.40661873066373605,
#    'topic_info': [('investigation', 0.11342337209691052),
#     ('reports', 0.10803080950133923),
#     ('incidents', 0.10297823230414185),
#     ('evidence', 0.07014332516354292),
#     ('citizens', 0.060657437923747747),
#     ('reporting', 0.056489246174143366),
#     ('force', 0.0504103875986269),
#     ('manager', 0.048797453635206364),
#     ('air', 0.047492648450824966),
#     ('user', 0.04667042587403855)]}],
#  [{'ksa_idx': 100,
#    'ksa_text': 'Planning for protection of intellectual property',
#    'topic_idx': 0,
#    'sim_score': 0.4347063830464055,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 101,
#    'ksa_text': 'Managing the implementation of access controls',
#    'topic_idx': 0,
#    'sim_score': 0.4566357755399045,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 107,
#    'ksa_text': 'Measuring the effectiveness of a security program metrics .',
#    'topic_idx': 0,
#    'sim_score': 0.4456462950247211,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 107,
#    'ksa_text': 'Measuring the effectiveness of a security program metrics .',
#    'topic_idx': 1,
#    'sim_score': 0.4110635076187587,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 108,
#    'ksa_text': 'Security program addresses a. Physical Security b. Personnel Security c. System and Data Identification d. System security plans. e. Configuration and Patch management f. System Documentation g. Incident Response Program h. Disaster Recovery Program. i. Certification and Accreditation',
#    'topic_idx': 0,
#    'sim_score': 0.49676333376952697,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 108,
#    'ksa_text': 'Security program addresses a. Physical Security b. Personnel Security c. System and Data Identification d. System security plans. e. Configuration and Patch management f. System Documentation g. Incident Response Program h. Disaster Recovery Program. i. Certification and Accreditation',
#    'topic_idx': 1,
#    'sim_score': 0.43069125394948693,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 108,
#    'ksa_text': 'Security program addresses a. Physical Security b. Personnel Security c. System and Data Identification d. System security plans. e. Configuration and Patch management f. System Documentation g. Incident Response Program h. Disaster Recovery Program. i. Certification and Accreditation',
#    'topic_idx': 2,
#    'sim_score': 0.4302782180782432,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]},
#   {'ksa_idx': 108,
#    'ksa_text': 'Security program addresses a. Physical Security b. Personnel Security c. System and Data Identification d. System security plans. e. Configuration and Patch management f. System Documentation g. Incident Response Program h. Disaster Recovery Program. i. Certification and Accreditation',
#    'topic_idx': 3,
#    'sim_score': 0.4077204979192919,
#    'topic_info': [('certification', 0.1706317449285472),
#     ('accreditation', 0.1619617614286396),
#     ('assurance', 0.09508500350097875),
#     ('information', 0.054648999807571014),
#     ('the', 0.05325144580527363),
#     ('program', 0.0492785475559477),
#     ('process', 0.040298560898521706),
#     ('and', 0.03997922281563495),
#     ('in', 0.03970705272689851),
#     ('such', 0.03343532950310528)]}],
#  [{'ksa_idx': 109,
#    'ksa_text': 'Security Policies. a. Compliance with Applicable Laws and Regulations b. Security best practices and frameworks.',
#    'topic_idx': 0,
#    'sim_score': 0.4261071161701567,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [{'ksa_idx': 111,
#    'ksa_text': 'Goals and objectives of a security program.',
#    'topic_idx': 0,
#    'sim_score': 0.5332102834349011,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 111,
#    'ksa_text': 'Goals and objectives of a security program.',
#    'topic_idx': 1,
#    'sim_score': 0.4133225341229662,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [{'ksa_idx': 113,
#    'ksa_text': 'Security Awareness, Training and Education',
#    'topic_idx': 0,
#    'sim_score': 0.4242346178883212,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 114,
#    'ksa_text': 'Security Baselining',
#    'topic_idx': 0,
#    'sim_score': 0.42598948823939337,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 114,
#    'ksa_text': 'Security Baselining',
#    'topic_idx': 1,
#    'sim_score': 0.42466751146511045,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [{'ksa_idx': 116,
#    'ksa_text': 'Risk Measurement and Evaluation Methodologies',
#    'topic_idx': 0,
#    'sim_score': 0.4028632589410178,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [{'ksa_idx': 118,
#    'ksa_text': 'Risk Management Processes',
#    'topic_idx': 0,
#    'sim_score': 0.40646030027558877,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [{'ksa_idx': 121,
#    'ksa_text': 'Communication of Risk',
#    'topic_idx': 0,
#    'sim_score': 0.5126035643525477,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 122,
#    'ksa_text': 'Ability to identify systemic security issues based on the analysis of vulnerability and configuration data.',
#    'topic_idx': 0,
#    'sim_score': 0.522255701814647,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 122,
#    'ksa_text': 'Ability to identify systemic security issues based on the analysis of vulnerability and configuration data.',
#    'topic_idx': 1,
#    'sim_score': 0.4479405506022884,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 123,
#    'ksa_text': 'Ability to analyze malware.',
#    'topic_idx': 0,
#    'sim_score': 0.44575176748265055,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]}],
#  [{'ksa_idx': 124,
#    'ksa_text': 'Ability to conduct vulnerability scans and recognize vulnerabilities in security systems.',
#    'topic_idx': 0,
#    'sim_score': 0.5522586114284896,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 124,
#    'ksa_text': 'Ability to conduct vulnerability scans and recognize vulnerabilities in security systems.',
#    'topic_idx': 1,
#    'sim_score': 0.4336064156551803,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 124,
#    'ksa_text': 'Ability to conduct vulnerability scans and recognize vulnerabilities in security systems.',
#    'topic_idx': 2,
#    'sim_score': 0.4254089141534273,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]}],
#  [],
#  [],
#  [{'ksa_idx': 127,
#    'ksa_text': 'Ability to share meaningful insights about the context of an organization s threat environment that improve its risk management posture.',
#    'topic_idx': 0,
#    'sim_score': 0.4779559421403561,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 127,
#    'ksa_text': 'Ability to share meaningful insights about the context of an organization s threat environment that improve its risk management posture.',
#    'topic_idx': 1,
#    'sim_score': 0.4451886780666532,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [{'ksa_idx': 129,
#    'ksa_text': 'Ability to apply cybersecurity and privacy principles to organizational requirements relevant to confidentiality, integrity, availability, authentication, non repudiation .',
#    'topic_idx': 0,
#    'sim_score': 0.41260796290950386,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 135,
#    'ksa_text': 'Knowledge of cybersecurity and privacy principles.',
#    'topic_idx': 0,
#    'sim_score': 0.46543524938111147,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 135,
#    'ksa_text': 'Knowledge of cybersecurity and privacy principles.',
#    'topic_idx': 1,
#    'sim_score': 0.44547108834685656,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 136,
#    'ksa_text': 'Knowledge of cyber threats and vulnerabilities.',
#    'topic_idx': 0,
#    'sim_score': 0.4991449918412867,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 136,
#    'ksa_text': 'Knowledge of cyber threats and vulnerabilities.',
#    'topic_idx': 1,
#    'sim_score': 0.4468069329150903,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 137,
#    'ksa_text': 'Knowledge of specific operational impacts of cybersecurity lapses.',
#    'topic_idx': 0,
#    'sim_score': 0.43186310412677287,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [{'ksa_idx': 139,
#    'ksa_text': 'Knowledge of application vulnerabilities.',
#    'topic_idx': 0,
#    'sim_score': 0.5218212774927462,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 139,
#    'ksa_text': 'Knowledge of application vulnerabilities.',
#    'topic_idx': 1,
#    'sim_score': 0.45724178620772615,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]},
#   {'ksa_idx': 139,
#    'ksa_text': 'Knowledge of application vulnerabilities.',
#    'topic_idx': 2,
#    'sim_score': 0.4379886047945555,
#    'topic_info': [('security', 0.08539322226783583),
# ...
#     ('security', 0.04258055269229748)]}],
#  [],
#  [],
#  [{'ksa_idx': 244,
#    'ksa_text': 'Skill in recognizing vulnerabilities in security systems. e.g., vulnerability and compliance scanning .',
#    'topic_idx': 0,
#    'sim_score': 0.5161975408769671,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [{'ksa_idx': 247,
#    'ksa_text': 'Skill in using security event correlation tools.',
#    'topic_idx': 0,
#    'sim_score': 0.41051854384197417,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 248,
#    'ksa_text': 'Skill to develop insights about the context of an organization s threat environment',
#    'topic_idx': 0,
#    'sim_score': 0.454931789844555,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 248,
#    'ksa_text': 'Skill to develop insights about the context of an organization s threat environment',
#    'topic_idx': 1,
#    'sim_score': 0.44752482460893983,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [{'ksa_idx': 250,
#    'ksa_text': 'Skill to apply cybersecurity and privacy principles to organizational requirements relevant to confidentiality, integrity, availability, authentication, non repudiation .',
#    'topic_idx': 0,
#    'sim_score': 0.40204635962671664,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 254,
#    'ksa_text': 'Correlate incident data to identify specific vulnerabilities and make recommendations that enable expeditious remediation.',
#    'topic_idx': 0,
#    'sim_score': 0.47440968320392685,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 258,
#    'ksa_text': 'Perform cyber defense incident triage, to include determining scope, urgency, and potential impact, identifying the specific vulnerability, and making recommendations that enable expeditious remediation.',
#    'topic_idx': 0,
#    'sim_score': 0.44352771471668867,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 258,
#    'ksa_text': 'Perform cyber defense incident triage, to include determining scope, urgency, and potential impact, identifying the specific vulnerability, and making recommendations that enable expeditious remediation.',
#    'topic_idx': 1,
#    'sim_score': 0.41378998656598864,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 262,
#    'ksa_text': 'Prepare audit reports that identify technical and procedural findings, and provide recommended remediation strategies solutions.',
#    'topic_idx': 0,
#    'sim_score': 0.4057604942565649,
#    'topic_info': [('investigation', 0.11342337209691052),
#     ('reports', 0.10803080950133923),
#     ('incidents', 0.10297823230414185),
#     ('evidence', 0.07014332516354292),
#     ('citizens', 0.060657437923747747),
#     ('reporting', 0.056489246174143366),
#     ('force', 0.0504103875986269),
#     ('manager', 0.048797453635206364),
#     ('air', 0.047492648450824966),
#     ('user', 0.04667042587403855)]}],
#  [],
#  [],
#  [{'ksa_idx': 265,
#    'ksa_text': 'Write and publish cyber defense techniques, guidance, and reports on incident findings to appropriate constituencies.',
#    'topic_idx': 0,
#    'sim_score': 0.4033217221473678,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [{'ksa_idx': 267,
#    'ksa_text': 'Employ approved defense in depth principles and practices e.g., defense in multiple places, layered defenses, security robustness .',
#    'topic_idx': 0,
#    'sim_score': 0.4234953025952212,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [{'ksa_idx': 269,
#    'ksa_text': 'Serve as technical expert and liaison to law enforcement personnel and explain incident details as required.',
#    'topic_idx': 0,
#    'sim_score': 0.41417985142681235,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [],
#  [],
#  [{'ksa_idx': 273,
#    'ksa_text': 'Assist in the construction of signatures which can be implemented on cyber defense network tools in response to new or observed threats within the network environment or enclave.',
#    'topic_idx': 0,
#    'sim_score': 0.4761244156373693,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 273,
#    'ksa_text': 'Assist in the construction of signatures which can be implemented on cyber defense network tools in response to new or observed threats within the network environment or enclave.',
#    'topic_idx': 1,
#    'sim_score': 0.40615612410672725,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [],
#  [],
#  [{'ksa_idx': 276,
#    'ksa_text': 'Write and publish after action reviews.',
#    'topic_idx': 0,
#    'sim_score': 0.4321713757884572,
#    'topic_info': [('investigation', 0.11342337209691052),
#     ('reports', 0.10803080950133923),
#     ('incidents', 0.10297823230414185),
#     ('evidence', 0.07014332516354292),
#     ('citizens', 0.060657437923747747),
#     ('reporting', 0.056489246174143366),
#     ('force', 0.0504103875986269),
#     ('manager', 0.048797453635206364),
#     ('air', 0.047492648450824966),
#     ('user', 0.04667042587403855)]}],
#  [{'ksa_idx': 277,
#    'ksa_text': 'Analyze and report organizational security posture trends.',
#    'topic_idx': 0,
#    'sim_score': 0.46500930416895697,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 278,
#    'ksa_text': 'Analyze and report system security posture trends.',
#    'topic_idx': 0,
#    'sim_score': 0.48983231697065827,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]},
#   {'ksa_idx': 278,
#    'ksa_text': 'Analyze and report system security posture trends.',
#    'topic_idx': 1,
#    'sim_score': 0.4402141364166373,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [{'ksa_idx': 279,
#    'ksa_text': 'Assess adequate access controls based on principles of least privilege and need to know.',
#    'topic_idx': 0,
#    'sim_score': 0.46875947476851765,
#    'topic_info': [('information', 0.06450967280480616),
#     ('unauthorized', 0.047670656778752554),
#     ('systems', 0.0474598990239651),
#     ('and', 0.04632859350294156),
#     ('to', 0.04337562974840433),
#     ('privacy', 0.04192664972731174),
#     ('access', 0.041355428666108605),
#     ('against', 0.03893188903250376),
#     ('prevent', 0.03621954325818668),
#     ('accessibility', 0.03613772256439429)]}],
#  [],
#  [{'ksa_idx': 281,
#    'ksa_text': 'Assess and monitor cybersecurity related to system implementation and testing practices.',
#    'topic_idx': 0,
#    'sim_score': 0.4076815212432856,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 281,
#    'ksa_text': 'Assess and monitor cybersecurity related to system implementation and testing practices.',
#    'topic_idx': 1,
#    'sim_score': 0.40601463300560586,
#    'topic_info': [('hardware', 0.18011414935828224),
#     ('software', 0.1799388538387781),
#     ('critical', 0.05706150495544421),
#     ('install', 0.05651044109282909),
#     ('analyze', 0.054141419998731975),
#     ('support', 0.05366212345028111),
#     ('monitoring', 0.04976012365805644),
#     ('and', 0.04715789990719414),
#     ('tests', 0.04679185061140643),
#     ('security', 0.04258055269229748)]}],
#  [],
#  [{'ksa_idx': 283,
#    'ksa_text': 'Provides cybersecurity recommendations to leadership based on significant threats and vulnerabilities.',
#    'topic_idx': 0,
#    'sim_score': 0.4667299690977079,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 283,
#    'ksa_text': 'Provides cybersecurity recommendations to leadership based on significant threats and vulnerabilities.',
#    'topic_idx': 1,
#    'sim_score': 0.4298178886874064,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}],
#  [{'ksa_idx': 284,
#    'ksa_text': 'Work with stakeholders to resolve computer security incidents and vulnerability compliance.',
#    'topic_idx': 0,
#    'sim_score': 0.4429358680187907,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]}],
#  [],
#  [],
#  [{'ksa_idx': 287,
#    'ksa_text': 'Make recommendations regarding the selection of cost effective security controls to mitigate risk e.g., protection of information, systems and processes .',
#    'topic_idx': 0,
#    'sim_score': 0.4449956869756308,
#    'topic_info': [('vulnerabilities', 0.08127912833734274),
#     ('identify', 0.07051248532026982),
#     ('risks', 0.06976112365770233),
#     ('vulnerability', 0.05850702039482417),
#     ('risk', 0.04521581582197221),
#     ('and', 0.044031738573732396),
#     ('assessments', 0.040991157701148834),
#     ('systems', 0.039176227310131484),
#     ('to', 0.0389712415736714),
#     ('protection', 0.0370126287267103)]},
#   {'ksa_idx': 287,
#    'ksa_text': 'Make recommendations regarding the selection of cost effective security controls to mitigate risk e.g., protection of information, systems and processes .',
#    'topic_idx': 1,
#    'sim_score': 0.44208112112329667,
#    'topic_info': [('security', 0.08539322226783583),
#     ('and', 0.03981732720018356),
#     ('engineering', 0.03680518948452061),
#     ('gpo', 0.033910851122725114),
#     ('architecture', 0.03207985712523292),
#     ('it', 0.03193575225919073),
#     ('risk', 0.029052051740731753),
#     ('requirements', 0.02874419339080682),
#     ('planning', 0.027846378290196983),
#     ('to', 0.026430889298259028)]}]]

# %%
topic_model.get_topic(3)
# Out:
# [('cyber', 0.08515743915573751),
#  ('cybersecurity', 0.061543671236926764),
#  ('army', 0.04530453213380502),
#  ('will', 0.0415931611115692),
#  ('the', 0.041398049622688886),
#  ('as', 0.038721290691280184),
#  ('you', 0.03583871417004505),
#  ('for', 0.032958411127075475),
#  ('cio', 0.03221181276091664),
#  ('of', 0.028662075369281965)]

# %%
ksa | matched | similar

# %%
match,sim = {topic_idx, info, score}

# %%
t2=BERTopic.load('../data/results/usa_jobs/similarity_match/topicModel', embedding_model=model)

# %%
t2.get_topic_info()
# Out:
#     Topic  Count                                               Name
# 0      -1    260                             -1_and_security_the_of
# 1       0     73                      0_work_mission_subordinate_of
# 2       1     56     1_vulnerabilities_identify_risks_vulnerability
# 3       2     53             2_information_unauthorized_systems_and
# 4       3     39                    3_cyber_cybersecurity_army_will
# 5       4     38           4_cyberspace_tactical_operator_operators
# 6       5     32                     5_security_and_engineering_gpo
# 7       6     30                6_established_comprehensive_and_ais
# 8       7     29                       7_duties_include_but_limited
# 9       8     29               8_comsec_cryptographic_key_materials
# 10      9     27                 9_infosec_specialist_as_technology
# 12     10     26        10_investigation_reports_incidents_evidence
# 11     11     26          11_provide_development_support_architects
# 13     12     25                   12_network_systems_area_networks
# 14     13     21                  13_assigned_duties_performs_other
# 15     14     20                      14_performance_full_duties_12
# 16     15     19                        15_ais_implements_shelf_off
# 17     16     19              16_hardware_software_critical_install
# 18     17     18          17_veterans_preference_this_consideration
# 19     18     17                           18_sci_all_manuals_scifs
# 20     19     14  19_certification_accreditation_assurance_infor...
# 21     20     13                         20_office_schedule_no_hire

# %%
topic_model.visualize_topics()
# Out:
# <div>                            <div id="1d873001-b3cf-4963-9756-7479cc46ab3c" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d873001-b3cf-4963-9756-7479cc46ab3c")) {                    Plotly.newPlot(                        "1d873001-b3cf-4963-9756-7479cc46ab3c",                        [{"customdata":[[0,"work | mission | subordinate | of | and",73],[1,"vulnerabilities | identify | risks | vulnerability | risk",56],[2,"information | unauthorized | systems | and | to",53],[3,"cyber | cybersecurity | army | will | the",39],[4,"cyberspace | tactical | operator | operators | advanced",38],[5,"security | and | engineering | gpo | architecture",32],[6,"established | comprehensive | and | ais | go",30],[7,"duties | include | but | limited | the",29],[8,"comsec | cryptographic | key | materials | management",29],[9,"infosec | specialist | as | technology | information",27],[10,"investigation | reports | incidents | evidence | citizens",26],[11,"provide | development | support | architects | developers",26],[12,"network | systems | area | networks | installation",25],[13,"assigned | duties | performs | other | as",21],[14,"performance | full | duties | 12 | description",20],[15,"ais | implements | shelf | off | local",19],[16,"hardware | software | critical | install | analyze",19],[17,"veterans | preference | this | consideration | grade",18],[18,"sci | all | manuals | scifs | facilities",17],[19,"certification | accreditation | assurance | information | the",14],[20,"office | schedule | no | hire | direct",13]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[73,56,53,39,38,32,30,29,29,27,26,26,25,21,20,19,19,18,17,14,13],"sizemode":"area","sizeref":0.045625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[7.651059627532959,10.409074783325195,7.475372791290283,7.599323272705078,7.538519859313965,9.767374992370605,9.23530101776123,9.273592948913574,-3.52713942527771,7.860800743103027,-2.869253396987915,10.137723922729492,8.950654983520508,9.674508094787598,9.932302474975586,8.653443336486816,-2.869020700454712,9.616668701171875,-3.35913348197937,-3.086599111557007,9.336499214172363],"xaxis":"x","y":[-6.3614959716796875,-7.787710666656494,-7.649653434753418,-6.797530651092529,-6.168164253234863,-7.858137130737305,-8.067501068115234,-8.44755744934082,12.544894218444824,-7.451066493988037,1.383583903312683,-8.089900970458984,-8.093085289001465,-9.48678207397461,-9.23610782623291,-8.081779479980469,1.3833179473876953,-10.116737365722656,12.367709159851074,12.108419418334961,-10.458721160888672],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside" ...
