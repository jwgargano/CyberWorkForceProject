# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity as cs
import pandas as pd
import re
import numpy as np

# %%
# example KSA 
baseline =[
'Knowledge of computer networking concepts and protocols, and network security methodologies.',
'Knowledge of laws, regulations, policies, and ethics as they relate to cybersecurity and privacy.',
'Knowledge of specific operational impacts of cybersecurity lapses.',
'Knowledge of cyber defense and vulnerability assessment tools and their capabilities.',
'Knowledge of cryptography and cryptographic key management concepts',
'Knowledge of Security Assessment and Authorization process.',
'Knowledge of vulnerability information dissemination sources (e.g., alerts, advisories, errata, and bulletins).',
'Knowledge of cybersecurity and privacy principles and organizational requirements (relevant to confidentiality, integrity, availability, authentication, non-repudiation).',
'Knowledge of Risk Management Framework (RMF) requirements.',
'Knowledge of information technology (IT) security principles and methods (e.g., firewalls, demilitarized zones, encryption).',
'Knowledge of network security architecture concepts including topology, protocols, components, and principles (e.g., application of defense-in-depth).',
'Knowledge of security architecture concepts and enterprise architecture reference models (e.g., Zachman, Federal Enterprise Architecture [FEA]).',
'Knowledge of security models (e.g., Bell-LaPadula model, Biba integrity model, Clark-Wilson integrity model)',
'Knowledge of laws, policies, procedures, or governance relevant to cybersecurity for critical infrastructures.',
'Knowledge of embedded systems.',
'Knowledge of penetration testing principles, tools, and techniques.',
'Knowledge of controls related to the use, processing, storage, and transmission of data.',
'Knowledge of Application Security Risks (e.g. Open Web Application Security Project Top 10 list)',
]

# %%
baseline = [re.sub('Knowledge of ', '', base).lower() for base in baseline]

# %%
baseline
# Out:
# ['computer networking concepts and protocols, and network security methodologies.',
#  'laws, regulations, policies, and ethics as they relate to cybersecurity and privacy.',
#  'specific operational impacts of cybersecurity lapses.',
#  'cyber defense and vulnerability assessment tools and their capabilities.',
#  'cryptography and cryptographic key management concepts',
#  'security assessment and authorization process.',
#  'vulnerability information dissemination sources (e.g., alerts, advisories, errata, and bulletins).',
#  'cybersecurity and privacy principles and organizational requirements (relevant to confidentiality, integrity, availability, authentication, non-repudiation).',
#  'risk management framework (rmf) requirements.',
#  'information technology (it) security principles and methods (e.g., firewalls, demilitarized zones, encryption).',
#  'network security architecture concepts including topology, protocols, components, and principles (e.g., application of defense-in-depth).',
#  'security architecture concepts and enterprise architecture reference models (e.g., zachman, federal enterprise architecture [fea]).',
#  'security models (e.g., bell-lapadula model, biba integrity model, clark-wilson integrity model)',
#  'laws, policies, procedures, or governance relevant to cybersecurity for critical infrastructures.',
#  'embedded systems.',
#  'penetration testing principles, tools, and techniques.',
#  'controls related to the use, processing, storage, and transmission of data.',
#  'application security risks (e.g. open web application security project top 10 list)']

# %%
# import usajobs dataset and create single description column
file = './Data/Cleaned Data/USAJobs.csv'

# %%
df = pd.read_csv(file)

# %%
df['desc'] = df['Duties'] + df['Qualifications']

# %%
# get sample of 10 for testing
all_desc = df['desc'][0:100].tolist()

# %%
# BERT Model name from hugging face 
# https://huggingface.co/models?library=sentence-transformers&pipeline_tag=sentence-similarity&sort=downloads
# model_name = 'sentence-transformers/all-MiniLM-L6-v2'
# model_name = 'sentence-transformers/all-mpnet-base-v2'
model_name = 'sentence-transformers/paraphrase-distilroberta-base-v2' #did the best so far...

# %%
# Initilize Bert Model
model = SentenceTransformer(model_name)

# %%
# encodes job descriptions to vectors
vecs = model.encode(all_desc)

# %%
vecs.shape
# Out:
# (100, 768)

# %%
# Cosine Similarity between job[0] and all other jobs
cs(
    [vecs[0]],
    vecs[1:]
)
# Out:
# array([[0.74492365, 0.73159015, 0.7142055 , 0.74809885, 0.7377205 ,
#         0.68225664, 0.6713934 , 0.74862325, 0.7670659 , 0.769273  ,
#         0.6565379 , 0.76355755, 0.7326689 , 0.67277485, 0.33671406,
#         0.7657068 , 0.8525787 , 0.8525787 , 0.8666339 , 0.8170122 ,
#         0.70726585, 0.46950716, 0.65344226, 0.6177583 , 0.74820095,
#         0.69521964, 0.69521964, 0.68346786, 0.691043  , 0.59580827,
#         0.7502958 , 0.68230313, 0.70632005, 0.7532674 , 0.6080156 ,
#         0.69000006, 0.59580827, 0.6769328 , 0.74894714, 0.817032  ,
#         0.70178396, 0.73336434, 0.6039961 , 0.53137875, 0.6426012 ,
#         0.6017817 , 0.5314803 , 0.7210504 , 0.74505395, 0.65438676,
#         0.7444533 , 0.7757393 , 0.6738914 , 0.7147994 , 0.48069674,
#         0.6547243 , 0.5176529 , 0.6990848 , 0.5822221 , 0.62251806,
#         0.75892854, 0.6066226 , 0.6593085 , 0.5784451 , 0.66064274,
#         0.76252043, 0.59202975, 0.6304366 , 0.7682084 , 0.67989635,
#         0.6281711 , 0.5966324 , 0.6927748 , 0.7985371 , 0.52804756,
#         0.7067206 , 0.68960047, 0.68960047, 0.76585   , 0.76585   ,
#         0.565738  , 0.68982786, 0.7542057 , 0.68787265, 0.7335936 ,
#         0.69105536, 0.69716275, 0.7633546 , 0.7633546 , 0.7513955 ,
#         0.74548286, 0.5529047 , 0.7323364 , 0.45254934, 0.6841905 ,
#         0.6915968 , 0.6934136 , 0.6956691 , 0.63878065]], dtype=float32)

# %%
# split desc into sentences
all_sents = []

for doc in all_desc:
    sents = []
    sent_means =[]
    cleaned = re.sub('•', '', doc).lower()
    cleaned = re.sub('-', '', cleaned)
    sents = re.split('\/n|\.', cleaned)
    sents = [sent.strip().lower() for sent in sents if len(sent.strip()) > 1]
    all_sents.append(sents)

# %%
all_sents[0]
# Out:
# ['serves as a technical expert and performs a wide range and long term it security management functions in one or more of the following areas: administrative operations, information technology support, it security development oversight, certification and accreditation (c&a), and assisting with implementing and adherence of hhs enterprise architecture (ea) security plans',
#  'assists the soc information technology manager with the developing processes for information system security c&a, evaluation and risk assessment plans along with other mandated security assessments',
#  'coordinate with it system administrators, developers and engineers to address security vulnerabilities by performing audits and risk assessments to identify vulnerabilities in it systems',
#  'performs security engineering and architecture and services within policy and planning, security, security engineering, systems analysis, web services, applications software, operating systems, and cross domain solutions',
#  'develops and/or interprets policies, procedures, and strategies governing the planning and delivery of it product and services',
#  'assists with the preparation of annual security assessments and various security audits required by federal mandate',
#  'apply information security/information assurance policies, principles and practices in the delivery of all information technology (it) systems and services',
#  'specialized experience: qualifying experience for gs13 includes one year of specialized experience comparable to gs12 which is directly related to the work of the position',
#  'for this position, specialized experience is experience providing guidance in technology infrastructure that support the mission, programs and initiatives related to public health and medical emergency management and response',
#  'andadditional requirements: attention to detail  is thorough when performing work and conscientious about attending to detail',
#  'customer service  works with clients and customers (that is, any individuals who use or receive the services or products that your work unit produces, including the general public, individuals who work in the agency, other agencies, or organizations outside the government) to assess their needs, provide information or assistance, resolve their problems, or satisfy their expectations; knows about available products and services; is committed to providing quality products and services',
#  'oral communication  expresses information (for example, ideas or facts) to individuals or groups effectively, taking into account the audience and nature of the information (for example, technical, sensitive, controversial); makes clear and convincing oral presentations; listens to others, attends to nonverbal cues, and responds appropriately',
#  'problem solving  identifies problems; determines accuracy and relevance of information; uses sound judgment to generate and evaluate alternatives, and to make recommendations',
#  'documenting experience: in accordance with office of personnel management policy, federal employees are assumed to have gained experience by performing duties and responsibilities appropriate for their official series and grade level as described in their position description',
#  "experience that would not normally be part of the employee's position is creditable, however, when documented by satisfactory evidence, such as a signed memorandum from the employee's supervisor or an sf50 or sf52 documenting an official detail or other official assignment",
#  'the documentation must indicate whether the duties were performed full time or, if part time, the "percentage of times" the other duties were performed',
#  "it is expected that this documentation is included in the employee's official personnel record",
#  'in order to receive credit for experience in your resume that is not within the official series and grade level of your official position, you must provide a copy of the appropriate documentation of such experience as indicated above']

# %%
# encode all sentences
all_sents_vecs = []
for sent in all_sents:
    sent_vecs = model.encode(sent)
    all_sents_vecs.append(sent_vecs)

# %%
# vectorize the baseline sample
baseline_vecs = []
for sent in baseline:
    baseline_vecs.append(model.encode(sent.lower()))

# %%
# Try using each KSA and compare it to each sentence for each job description
# Find sentences that matches (x > 0.7), similar matches ( 0.7< x >0.5), missing ( x < 0.5)
all_matches = []
all_similar =[]
all_missing =[]
for idx, sent in enumerate(baseline_vecs):
    print('ksa', idx)
    for idx2, job_sents in enumerate(all_sents_vecs):
        print('..job ', idx2)
        matched=[]
        similar=[]
        missing=[]
        val = cs([sent], job_sents)
#         print('cs vals', val)
        for idx3, num in enumerate(val[0]):
            print('.....sent', idx3)
            temp = {}
            if num >=0.7:
                print('Possible Sentence Match! for baseline sent ', idx, ' and job ', idx2, ' at ', idx3)
                print(baseline[idx], ' <> ')
                print(all_sents[idx2][idx3])
                temp['job_idx'] = idx2
                temp['sentence_idx'] = idx3
                temp['ksa_idx'] = idx
                temp['sentence_text'] = all_sents[idx2][idx3]
                temp['ksa_text'] = baseline[idx]
                temp['sim_score'] = num
                matched.append(temp)
            elif num < 0.7 and num > 0.5:
                temp['job_idx'] = idx2
                temp['sentence_idx'] = idx3
                temp['ksa_idx'] = idx
                temp['sentence_text'] = all_sents[idx2][idx3]
                temp['ksa_text'] = baseline[idx]
                temp['sim_score'] = num
                similar.append(temp)
            else:
                temp['job_idx'] = idx2
                temp['sentence_idx'] = idx3
                temp['ksa_idx'] = idx
                temp['sentence_text'] = all_sents[idx2][idx3]
                temp['ksa_text'] = baseline[idx]
                temp['sim_score'] = num
                missing.append(temp)
    all_matches.append(matched)
    all_similar.append(similar)
    all_missing.append(missing)
    print('**\n**')
# Out:
# ksa 0
# ..job  0
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  1
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# ..job  2
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# ..job  3
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  4
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# ..job  5
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# ..job  6
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  7
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  8
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# ..job  9
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  10
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  11
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# ..job  12
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  13
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# ..job  14
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# ..job  15
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# ..job  16
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# ..job  17
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  18
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  19
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  20
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# ..job  21
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# ..job  22
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# ..job  23
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# ..job  24
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  25
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  26
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# ..job  27
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# ..job  28
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  29
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  30
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  31
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# ..job  32
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# ..job  33
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  34
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# ..job  35
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  36
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# ..job  37
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  38
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# ..job  39
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  40
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# ..job  41
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  42
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# ..job  43
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  44
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# .....sent 63
# ..job  45
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  46
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# ..job  47
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# ..job  48
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# ..job  49
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# ..job  50
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  51
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  52
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# ..job  53
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# ..job  54
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# ..job  55
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# .....sent 63
# ..job  56
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  57
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# Possible Sentence Match! for baseline sent  0  and job  57  at  37
# computer networking concepts and protocols, and network security methodologies.  <>
# computer network defense  knowledge of defensive measures to detect, respond, and protect information, information systems, and networks from threats
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# ..job  58
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  59
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  60
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  61
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  62
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# ..job  63
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  64
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  65
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  66
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  67
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  68
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  69
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  70
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# ..job  71
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# ..job  72
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  73
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  74
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# ..job  75
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# .....sent 63
# ..job  76
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# ..job  77
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  78
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  79
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# ..job  80
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# ..job  81
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# ..job  82
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  83
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# ..job  84
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  85
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# ..job  86
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  87
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# Possible Sentence Match! for baseline sent  0  and job  87  at  16
# computer networking concepts and protocols, and network security methodologies.  <>
# knowledge of local area network security requirements and techniques for protecting computer systems from viruses, data tampering, and unauthorized system entry
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# ..job  88
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  89
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  90
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  91
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  92
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# ..job  93
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# ..job  94
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# ..job  95
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  96
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  97
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# ..job  98
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  99
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# **
# **
# ksa 1
# ..job  0
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  1
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# ..job  2
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# ..job  3
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  4
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# ..job  5
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# ..job  6
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  7
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  8
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# ..job  9
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  10
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  11
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# ..job  12
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  13
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# ..job  14
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# ..job  15
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# ..job  16
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# Possible Sentence Match! for baseline sent  1  and job  16  at  5
# laws, regulations, policies, and ethics as they relate to cybersecurity and privacy.  <>
# assess and manage privacy risks associated with cybersecurity programs, operations, and technology and ensure compliance with agency privacy program requirements
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# ..job  17
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  18
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  19
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  20
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# ..job  21
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# ..job  22
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# ..job  23
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# ..job  24
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  25
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  26
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# ..job  27
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# ..job  28
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  29
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  30
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  31
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# ..job  32
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# ..job  33
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  34
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# ..job  35
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  36
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# ..job  37
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  38
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# ..job  39
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  40
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# ..job  41
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  42
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# ...
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# .....sent 63
# ..job  56
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  57
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# ..job  58
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  59
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  60
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  61
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  62
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# ..job  63
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  64
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  65
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# ..job  66
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  67
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  68
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  69
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# ..job  70
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# ..job  71
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# ..job  72
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  73
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# ..job  74
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# ..job  75
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# .....sent 63
# ..job  76
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# ..job  77
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  78
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# ..job  79
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# ..job  80
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# ..job  81
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# ..job  82
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  83
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# ..job  84
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# ..job  85
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# ..job  86
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  87
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# ..job  88
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  89
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# ..job  90
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# ..job  91
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  92
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# .....sent 43
# .....sent 44
# .....sent 45
# .....sent 46
# .....sent 47
# .....sent 48
# .....sent 49
# .....sent 50
# .....sent 51
# .....sent 52
# .....sent 53
# .....sent 54
# .....sent 55
# .....sent 56
# .....sent 57
# .....sent 58
# .....sent 59
# .....sent 60
# .....sent 61
# .....sent 62
# ..job  93
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# ..job  94
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# .....sent 30
# .....sent 31
# .....sent 32
# .....sent 33
# .....sent 34
# .....sent 35
# .....sent 36
# .....sent 37
# .....sent 38
# .....sent 39
# .....sent 40
# .....sent 41
# .....sent 42
# ..job  95
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# .....sent 23
# .....sent 24
# .....sent 25
# .....sent 26
# .....sent 27
# .....sent 28
# .....sent 29
# ..job  96
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# .....sent 20
# .....sent 21
# .....sent 22
# ..job  97
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# ..job  98
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# ..job  99
# .....sent 0
# .....sent 1
# .....sent 2
# .....sent 3
# .....sent 4
# .....sent 5
# .....sent 6
# .....sent 7
# .....sent 8
# .....sent 9
# .....sent 10
# .....sent 11
# .....sent 12
# .....sent 13
# .....sent 14
# .....sent 15
# .....sent 16
# .....sent 17
# .....sent 18
# .....sent 19
# **
# **

# %%
all_matches
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 9,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'information technology (it) security principles and methods (e.g., firewalls, demilitarized zones, encryption).',
#    'sim_score': 0.7667952}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
all_similar
# Out:
# [[{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 0,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'computer networking concepts and protocols, and network security methodologies.',
#    'sim_score': 0.5896485},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 0,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'computer networking concepts and protocols, and network security methodologies.',
#    'sim_score': 0.6588025}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 1,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'laws, regulations, policies, and ethics as they relate to cybersecurity and privacy.',
#    'sim_score': 0.6013621},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 1,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'laws, regulations, policies, and ethics as they relate to cybersecurity and privacy.',
#    'sim_score': 0.57524556}],
#  [],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 3,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'cyber defense and vulnerability assessment tools and their capabilities.',
#    'sim_score': 0.5703944},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 3,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'cyber defense and vulnerability assessment tools and their capabilities.',
#    'sim_score': 0.57461005}],
#  [{'job_idx': 99,
#    'sentence_idx': 3,
#    'ksa_idx': 4,
#    'sentence_text': "provide support to the cam for accounting for and distributing controlled cryptographic items (cci) and cryptographic keymat required to support the battalion's numerous local and worldwide dod connections and systems and other government agencies, nato partners, and allied nations",
#    'ksa_text': 'cryptography and cryptographic key management concepts',
#    'sim_score': 0.54516864},
#   {'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 4,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'cryptography and cryptographic key management concepts',
#    'sim_score': 0.5936867},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 4,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'cryptography and cryptographic key management concepts',
#    'sim_score': 0.5338694}],
#  [{'job_idx': 99,
#    'sentence_idx': 1,
#    'ksa_idx': 5,
#    'sentence_text': 'review communication security violation reports, ensuring adequate investigation followups and casual determinations are made',
#    'ksa_text': 'security assessment and authorization process.',
#    'sim_score': 0.5232313},
#   {'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 5,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'security assessment and authorization process.',
#    'sim_score': 0.5497395},
#   {'job_idx': 99,
#    'sentence_idx': 14,
#    'ksa_idx': 5,
#    'sentence_text': 'specialized experience is defined as: (1) protecting classified and sensitive data; (2) investigating communications security violations; and (3) distributing controlled cryptographic items and cryptographic keying material',
#    'ksa_text': 'security assessment and authorization process.',
#    'sim_score': 0.5059052},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 5,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'security assessment and authorization process.',
#    'sim_score': 0.66253734}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 6,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'vulnerability information dissemination sources (e.g., alerts, advisories, errata, and bulletins).',
#    'sim_score': 0.51938814},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 6,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'vulnerability information dissemination sources (e.g., alerts, advisories, errata, and bulletins).',
#    'sim_score': 0.5395102}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 7,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'cybersecurity and privacy principles and organizational requirements (relevant to confidentiality, integrity, availability, authentication, non-repudiation).',
#    'sim_score': 0.6420915},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 7,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'cybersecurity and privacy principles and organizational requirements (relevant to confidentiality, integrity, availability, authentication, non-repudiation).',
#    'sim_score': 0.5900167}],
#  [],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 9,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'information technology (it) security principles and methods (e.g., firewalls, demilitarized zones, encryption).',
#    'sim_score': 0.63335973}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 10,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'network security architecture concepts including topology, protocols, components, and principles (e.g., application of defense-in-depth).',
#    'sim_score': 0.5609547},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 10,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'network security architecture concepts including topology, protocols, components, and principles (e.g., application of defense-in-depth).',
#    'sim_score': 0.67870927}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 11,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'security architecture concepts and enterprise architecture reference models (e.g., zachman, federal enterprise architecture [fea]).',
#    'sim_score': 0.54670715},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 11,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'security architecture concepts and enterprise architecture reference models (e.g., zachman, federal enterprise architecture [fea]).',
#    'sim_score': 0.5782529}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 12,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'security models (e.g., bell-lapadula model, biba integrity model, clark-wilson integrity model)',
#    'sim_score': 0.51688594},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 12,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'security models (e.g., bell-lapadula model, biba integrity model, clark-wilson integrity model)',
#    'sim_score': 0.5481487}],
#  [{'job_idx': 99,
#    'sentence_idx': 4,
#    'ksa_idx': 13,
#    'sentence_text': 'provide guidance and subjectmatter expertise for cryptography security, emission security, transmission security, comsec physical security, and accountability of comsec material and information',
#    'ksa_text': 'laws, policies, procedures, or governance relevant to cybersecurity for critical infrastructures.',
#    'sim_score': 0.60595995},
#   {'job_idx': 99,
#    'sentence_idx': 18,
#    'ksa_idx': 13,
#    'sentence_text': 'knowledge of it security principles and methods',
#    'ksa_text': 'laws, policies, procedures, or governance relevant to cybersecurity for critical infrastructures.',
#    'sim_score': 0.5997416}],
#  [],
#  [],
#  [],
#  []]

# %%
sent_total = 0
for x in all_sents:
    sent_total += len(x)
print(sent_total)
# Out:
# 2590

# %%
# not getting the best results? 
for idx, val in enumerate(baseline):
    print('ksa ', idx)
    matched_score = len(all_matches[idx])/sent_total
    similar_score = len(all_similar[idx])/sent_total
#     missing_score = len(all_missing[idx])/(len(all_desc)+ len(baseline))
    missing_score = 1 -(matched_score + similar_score)
    print('Match Score ==', matched_score)
    print('Similar Score == ', similar_score)
    print('Missing Score ==', missing_score)
# Out:
# ksa  0
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  1
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  2
# Match Score == 0.0
# Similar Score ==  0.0
# Missing Score == 1.0
# ksa  3
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  4
# Match Score == 0.0
# Similar Score ==  0.0011583011583011582
# Missing Score == 0.9988416988416988
# ksa  5
# Match Score == 0.0
# Similar Score ==  0.0015444015444015444
# Missing Score == 0.9984555984555985
# ksa  6
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  7
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  8
# Match Score == 0.0
# Similar Score ==  0.0
# Missing Score == 1.0
# ksa  9
# Match Score == 0.0003861003861003861
# Similar Score ==  0.0003861003861003861
# Missing Score == 0.9992277992277993
# ksa  10
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  11
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  12
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  13
# Match Score == 0.0
# Similar Score ==  0.0007722007722007722
# Missing Score == 0.9992277992277993
# ksa  14
# Match Score == 0.0
# Similar Score ==  0.0
# Missing Score == 1.0
# ksa  15
# Match Score == 0.0
# Similar Score ==  0.0
# Missing Score == 1.0
# ksa  16
# Match Score == 0.0
# Similar Score ==  0.0
# Missing Score == 1.0
# ksa  17
# Match Score == 0.0
# Similar Score ==  0.0
# Missing Score == 1.0
